# %% [markdown]
# http://earthquake.usgs.gov/fdsnws/event/1/

# %%
# %matplotlib inline
import sys
import numpy as np
import urllib.request
from datetime import date

firstYear = 1973
thisYear = date.today().year
thisMonth = date.today().month
thisDay = date.today().day

filou = open("earthquakes.csv", "w", encoding="utf-8")

filou.write("time,latitude,longitude,depth,mag,magType,nst,gap,dmin,rms,net,id,updated,place,type\n")
for annee in range(firstYear,thisYear+1):
    lastMonth=12
    if annee==thisYear:
        lastMonth = thisMonth
    for mois in range(1,lastMonth+1):
        print("Récupération des données de ",annee,".",mois)
        startday=str(annee)+"-"+str(mois)+"-01"
        endday=str(annee+int(mois/12))+"-"+str((mois%12)+1)+"-01"
        url = "http://comcat.cr.usgs.gov/fdsnws/event/1/query?&minmagnitude=0&format=csv&orderby=time-asc&starttime="+startday+"%2000:00:00&endtime="+endday+"%2000:00:00"
        csvsource = urllib.request.urlopen(url)
        filou.write(csvsource.read().decode('utf-8').replace("time,latitude,longitude,depth,mag,magType,nst,gap,dmin,rms,net,id,updated,place,type\n",""))
# Out:
# Récupération des données de  1973 . 1
# Récupération des données de  1973 . 2
# Récupération des données de  1973 . 3
# Récupération des données de  1973 . 4
# Récupération des données de  1973 . 5
# Récupération des données de  1973 . 6
# Récupération des données de  1973 . 7
# Récupération des données de  1973 . 8
# Récupération des données de  1973 . 9
# Récupération des données de  1973 . 10
# Récupération des données de  1973 . 11
# Récupération des données de  1973 . 12
# Récupération des données de  1974 . 1
# Récupération des données de  1974 . 2
# Récupération des données de  1974 . 3
# Récupération des données de  1974 . 4
# Récupération des données de  1974 . 5
# Récupération des données de  1974 . 6
# Récupération des données de  1974 . 7
# Récupération des données de  1974 . 8
# Récupération des données de  1974 . 9
# Récupération des données de  1974 . 10
# Récupération des données de  1974 . 11
# Récupération des données de  1974 . 12
# Récupération des données de  1975 . 1
# Récupération des données de  1975 . 2
# Récupération des données de  1975 . 3
# Récupération des données de  1975 . 4
# Récupération des données de  1975 . 5
# Récupération des données de  1975 . 6
# Récupération des données de  1975 . 7
# Récupération des données de  1975 . 8
# Récupération des données de  1975 . 9
# Récupération des données de  1975 . 10
# Récupération des données de  1975 . 11
# Récupération des données de  1975 . 12
# Récupération des données de  1976 . 1
# Récupération des données de  1976 . 2
# Récupération des données de  1976 . 3
# Récupération des données de  1976 . 4
# Récupération des données de  1976 . 5
# Récupération des données de  1976 . 6
# Récupération des données de  1976 . 7
# Récupération des données de  1976 . 8
# Récupération des données de  1976 . 9
# Récupération des données de  1976 . 10
# Récupération des données de  1976 . 11
# Récupération des données de  1976 . 12
# Récupération des données de  1977 . 1
# Récupération des données de  1977 . 2
# Récupération des données de  1977 . 3
# Récupération des données de  1977 . 4
# Récupération des données de  1977 . 5
# Récupération des données de  1977 . 6
# Récupération des données de  1977 . 7
# Récupération des données de  1977 . 8
# Récupération des données de  1977 . 9
# Récupération des données de  1977 . 10
# Récupération des données de  1977 . 11
# Récupération des données de  1977 . 12
# Récupération des données de  1978 . 1
# Récupération des données de  1978 . 2
# Récupération des données de  1978 . 3
# Récupération des données de  1978 . 4
# Récupération des données de  1978 . 5
# Récupération des données de  1978 . 6
# Récupération des données de  1978 . 7
# Récupération des données de  1978 . 8
# Récupération des données de  1978 . 9
# Récupération des données de  1978 . 10
# Récupération des données de  1978 . 11
# Récupération des données de  1978 . 12
# Récupération des données de  1979 . 1
# Récupération des données de  1979 . 2
# Récupération des données de  1979 . 3
# Récupération des données de  1979 . 4
# Récupération des données de  1979 . 5
# Récupération des données de  1979 . 6
# Récupération des données de  1979 . 7
# Récupération des données de  1979 . 8
# Récupération des données de  1979 . 9
# Récupération des données de  1979 . 10
# Récupération des données de  1979 . 11
# Récupération des données de  1979 . 12
# Récupération des données de  1980 . 1
# Récupération des données de  1980 . 2
# Récupération des données de  1980 . 3
# Récupération des données de  1980 . 4
# Récupération des données de  1980 . 5
# Récupération des données de  1980 . 6
# Récupération des données de  1980 . 7
# Récupération des données de  1980 . 8
# Récupération des données de  1980 . 9
# Récupération des données de  1980 . 10
# Récupération des données de  1980 . 11
# Récupération des données de  1980 . 12
# Récupération des données de  1981 . 1
# Récupération des données de  1981 . 2
# Récupération des données de  1981 . 3
# Récupération des données de  1981 . 4
# Récupération des données de  1981 . 5
# Récupération des données de  1981 . 6
# Récupération des données de  1981 . 7
# Récupération des données de  1981 . 8
# Récupération des données de  1981 . 9
# Récupération des données de  1981 . 10
# Récupération des données de  1981 . 11
# Récupération des données de  1981 . 12
# Récupération des données de  1982 . 1
# Récupération des données de  1982 . 2
# Récupération des données de  1982 . 3
# Récupération des données de  1982 . 4
# Récupération des données de  1982 . 5
# Récupération des données de  1982 . 6
# Récupération des données de  1982 . 7
# Récupération des données de  1982 . 8
# Récupération des données de  1982 . 9
# Récupération des données de  1982 . 10
# Récupération des données de  1982 . 11
# Récupération des données de  1982 . 12
# Récupération des données de  1983 . 1
# Récupération des données de  1983 . 2
# Récupération des données de  1983 . 3
# Récupération des données de  1983 . 4
# Récupération des données de  1983 . 5
# Récupération des données de  1983 . 6
# Récupération des données de  1983 . 7
# Récupération des données de  1983 . 8
# Récupération des données de  1983 . 9
# Récupération des données de  1983 . 10
# Récupération des données de  1983 . 11
# Récupération des données de  1983 . 12
# Récupération des données de  1984 . 1
# Récupération des données de  1984 . 2
# Récupération des données de  1984 . 3
# Récupération des données de  1984 . 4
# Récupération des données de  1984 . 5
# Récupération des données de  1984 . 6
# Récupération des données de  1984 . 7
# Récupération des données de  1984 . 8
# Récupération des données de  1984 . 9
# Récupération des données de  1984 . 10
# Récupération des données de  1984 . 11
# Récupération des données de  1984 . 12
# Récupération des données de  1985 . 1
# Récupération des données de  1985 . 2
# Récupération des données de  1985 . 3
# Récupération des données de  1985 . 4
# Récupération des données de  1985 . 5
# Récupération des données de  1985 . 6
# Récupération des données de  1985 . 7
# Récupération des données de  1985 . 8
# Récupération des données de  1985 . 9
# Récupération des données de  1985 . 10
# Récupération des données de  1985 . 11
# Récupération des données de  1985 . 12
# Récupération des données de  1986 . 1
# Récupération des données de  1986 . 2
# Récupération des données de  1986 . 3
# Récupération des données de  1986 . 4
# Récupération des données de  1986 . 5
# Récupération des données de  1986 . 6
# Récupération des données de  1986 . 7
# Récupération des données de  1986 . 8
# Récupération des données de  1986 . 9
# Récupération des données de  1986 . 10
# Récupération des données de  1986 . 11
# Récupération des données de  1986 . 12
# Récupération des données de  1987 . 1
# Récupération des données de  1987 . 2
# Récupération des données de  1987 . 3
# Récupération des données de  1987 . 4
# Récupération des données de  1987 . 5
# Récupération des données de  1987 . 6
# Récupération des données de  1987 . 7
# Récupération des données de  1987 . 8
# Récupération des données de  1987 . 9
# Récupération des données de  1987 . 10
# Récupération des données de  1987 . 11
# Récupération des données de  1987 . 12
# Récupération des données de  1988 . 1
# Récupération des données de  1988 . 2
# Récupération des données de  1988 . 3
# Récupération des données de  1988 . 4
# Récupération des données de  1988 . 5
# Récupération des données de  1988 . 6
# Récupération des données de  1988 . 7
# Récupération des données de  1988 . 8
# Récupération des données de  1988 . 9
# Récupération des données de  1988 . 10
# Récupération des données de  1988 . 11
# Récupération des données de  1988 . 12
# Récupération des données de  1989 . 1
# Récupération des données de  1989 . 2
# Récupération des données de  1989 . 3
# Récupération des données de  1989 . 4
# Récupération des données de  1989 . 5
# Récupération des données de  1989 . 6
# Récupération des données de  1989 . 7
# Récupération des données de  1989 . 8
# Récupération des données de  1989 . 9
# Récupération des données de  1989 . 10
# Récupération des données de  1989 . 11
# Récupération des données de  1989 . 12
# Récupération des données de  1990 . 1
# Récupération des données de  1990 . 2
# Récupération des données de  1990 . 3
# Récupération des données de  1990 . 4
# Récupération des données de  1990 . 5
# Récupération des données de  1990 . 6
# Récupération des données de  1990 . 7
# Récupération des données de  1990 . 8
# Récupération des données de  1990 . 9
# Récupération des données de  1990 . 10
# Récupération des données de  1990 . 11
# Récupération des données de  1990 . 12
# Récupération des données de  1991 . 1
# Récupération des données de  1991 . 2
# Récupération des données de  1991 . 3
# Récupération des données de  1991 . 4
# Récupération des données de  1991 . 5
# Récupération des données de  1991 . 6
# Récupération des données de  1991 . 7
# Récupération des données de  1991 . 8
# Récupération des données de  1991 . 9
# Récupération des données de  1991 . 10
# Récupération des données de  1991 . 11
# Récupération des données de  1991 . 12
# Récupération des données de  1992 . 1
# Récupération des données de  1992 . 2
# Récupération des données de  1992 . 3
# Récupération des données de  1992 . 4
# Récupération des données de  1992 . 5
# Récupération des données de  1992 . 6
# Récupération des données de  1992 . 7
# Récupération des données de  1992 . 8
# Récupération des données de  1992 . 9
# Récupération des données de  1992 . 10
# Récupération des données de  1992 . 11
# Récupération des données de  1992 . 12
# Récupération des données de  1993 . 1
# Récupération des données de  1993 . 2
# Récupération des données de  1993 . 3
# Récupération des données de  1993 . 4
# Récupération des données de  1993 . 5
# Récupération des données de  1993 . 6
# Récupération des données de  1993 . 7
# Récupération des données de  1993 . 8
# Récupération des données de  1993 . 9
# Récupération des données de  1993 . 10
# Récupération des données de  1993 . 11
# Récupération des données de  1993 . 12
# Récupération des données de  1994 . 1
# Récupération des données de  1994 . 2
# Récupération des données de  1994 . 3
# Récupération des données de  1994 . 4
# Récupération des données de  1994 . 5
# Récupération des données de  1994 . 6
# Récupération des données de  1994 . 7
# Récupération des données de  1994 . 8
# Récupération des données de  1994 . 9
# Récupération des données de  1994 . 10
# Récupération des données de  1994 . 11
# Récupération des données de  1994 . 12
# Récupération des données de  1995 . 1
# Récupération des données de  1995 . 2
# Récupération des données de  1995 . 3
# Récupération des données de  1995 . 4
# Récupération des données de  1995 . 5
# Récupération des données de  1995 . 6
# Récupération des données de  1995 . 7
# Récupération des données de  1995 . 8
# Récupération des données de  1995 . 9
# Récupération des données de  1995 . 10
# Récupération des données de  1995 . 11
# Récupération des données de  1995 . 12
# Récupération des données de  1996 . 1
# Récupération des données de  1996 . 2
# Récupération des données de  1996 . 3
# Récupération des données de  1996 . 4
# Récupération des données de  1996 . 5
# Récupération des données de  1996 . 6
# Récupération des données de  1996 . 7
# Récupération des données de  1996 . 8
# Récupération des données de  1996 . 9
# Récupération des données de  1996 . 10
# Récupération des données de  1996 . 11
# Récupération des données de  1996 . 12
# Récupération des données de  1997 . 1
# Récupération des données de  1997 . 2
# Récupération des données de  1997 . 3
# Récupération des données de  1997 . 4
# Récupération des données de  1997 . 5
# Récupération des données de  1997 . 6
# Récupération des données de  1997 . 7
# Récupération des données de  1997 . 8
# Récupération des données de  1997 . 9
# Récupération des données de  1997 . 10
# Récupération des données de  1997 . 11
# Récupération des données de  1997 . 12
# Récupération des données de  1998 . 1
# Récupération des données de  1998 . 2
# Récupération des données de  1998 . 3
# Récupération des données de  1998 . 4
# Récupération des données de  1998 . 5
# Récupération des données de  1998 . 6
# Récupération des données de  1998 . 7
# Récupération des données de  1998 . 8
# Récupération des données de  1998 . 9
# Récupération des données de  1998 . 10
# Récupération des données de  1998 . 11
# Récupération des données de  1998 . 12
# Récupération des données de  1999 . 1
# Récupération des données de  1999 . 2
# Récupération des données de  1999 . 3
# Récupération des données de  1999 . 4
# Récupération des données de  1999 . 5
# Récupération des données de  1999 . 6
# Récupération des données de  1999 . 7
# Récupération des données de  1999 . 8
# Récupération des données de  1999 . 9
# Récupération des données de  1999 . 10
# Récupération des données de  1999 . 11
# Récupération des données de  1999 . 12
# Récupération des données de  2000 . 1
# Récupération des données de  2000 . 2
# Récupération des données de  2000 . 3
# Récupération des données de  2000 . 4
# Récupération des données de  2000 . 5
# Récupération des données de  2000 . 6
# Récupération des données de  2000 . 7
# Récupération des données de  2000 . 8
# Récupération des données de  2000 . 9
# Récupération des données de  2000 . 10
# Récupération des données de  2000 . 11
# Récupération des données de  2000 . 12
# Récupération des données de  2001 . 1
# Récupération des données de  2001 . 2
# Récupération des données de  2001 . 3
# Récupération des données de  2001 . 4
# Récupération des données de  2001 . 5
# Récupération des données de  2001 . 6
# Récupération des données de  2001 . 7
# Récupération des données de  2001 . 8
# Récupération des données de  2001 . 9
# Récupération des données de  2001 . 10
# Récupération des données de  2001 . 11
# Récupération des données de  2001 . 12
# Récupération des données de  2002 . 1
# Récupération des données de  2002 . 2
# Récupération des données de  2002 . 3
# Récupération des données de  2002 . 4
# Récupération des données de  2002 . 5
# Récupération des données de  2002 . 6
# Récupération des données de  2002 . 7
# Récupération des données de  2002 . 8
# Récupération des données de  2002 . 9
# Récupération des données de  2002 . 10
# Récupération des données de  2002 . 11
# Récupération des données de  2002 . 12
# Récupération des données de  2003 . 1
# Récupération des données de  2003 . 2
# Récupération des données de  2003 . 3
# Récupération des données de  2003 . 4
# Récupération des données de  2003 . 5
# Récupération des données de  2003 . 6
# Récupération des données de  2003 . 7
# Récupération des données de  2003 . 8
# Récupération des données de  2003 . 9
# Récupération des données de  2003 . 10
# Récupération des données de  2003 . 11
# Récupération des données de  2003 . 12
# Récupération des données de  2004 . 1
# Récupération des données de  2004 . 2
# Récupération des données de  2004 . 3
# Récupération des données de  2004 . 4
# Récupération des données de  2004 . 5
# Récupération des données de  2004 . 6
# Récupération des données de  2004 . 7
# Récupération des données de  2004 . 8
# Récupération des données de  2004 . 9
# Récupération des données de  2004 . 10
# Récupération des données de  2004 . 11
# Récupération des données de  2004 . 12
# Récupération des données de  2005 . 1
# Récupération des données de  2005 . 2
# Récupération des données de  2005 . 3
# Récupération des données de  2005 . 4
# Récupération des données de  2005 . 5
# Récupération des données de  2005 . 6
# Récupération des données de  2005 . 7
# Récupération des données de  2005 . 8
# Récupération des données de  2005 . 9
# Récupération des données de  2005 . 10
# Récupération des données de  2005 . 11
# Récupération des données de  2005 . 12
# Récupération des données de  2006 . 1
# Récupération des données de  2006 . 2
# Récupération des données de  2006 . 3
# Récupération des données de  2006 . 4
# Récupération des données de  2006 . 5
# Récupération des données de  2006 . 6
# Récupération des données de  2006 . 7
# Récupération des données de  2006 . 8
# Récupération des données de  2006 . 9
# Récupération des données de  2006 . 10
# Récupération des données de  2006 . 11
# Récupération des données de  2006 . 12
# Récupération des données de  2007 . 1
# Récupération des données de  2007 . 2
# Récupération des données de  2007 . 3
# Récupération des données de  2007 . 4
# Récupération des données de  2007 . 5
# Récupération des données de  2007 . 6
# Récupération des données de  2007 . 7
# Récupération des données de  2007 . 8
# Récupération des données de  2007 . 9
# Récupération des données de  2007 . 10
# Récupération des données de  2007 . 11
# Récupération des données de  2007 . 12
# Récupération des données de  2008 . 1
# Récupération des données de  2008 . 2
# Récupération des données de  2008 . 3
# Récupération des données de  2008 . 4
# Récupération des données de  2008 . 5
# Récupération des données de  2008 . 6
# Récupération des données de  2008 . 7
# Récupération des données de  2008 . 8
# Récupération des données de  2008 . 9
# Récupération des données de  2008 . 10
# Récupération des données de  2008 . 11
# Récupération des données de  2008 . 12
# Récupération des données de  2009 . 1
# Récupération des données de  2009 . 2
# Récupération des données de  2009 . 3
# Récupération des données de  2009 . 4
# Récupération des données de  2009 . 5
# Récupération des données de  2009 . 6
# Récupération des données de  2009 . 7
# Récupération des données de  2009 . 8
# Récupération des données de  2009 . 9
# Récupération des données de  2009 . 10
# Récupération des données de  2009 . 11
# Récupération des données de  2009 . 12
# Récupération des données de  2010 . 1
# Récupération des données de  2010 . 2
# Récupération des données de  2010 . 3
# Récupération des données de  2010 . 4
# Récupération des données de  2010 . 5
# Récupération des données de  2010 . 6
# Récupération des données de  2010 . 7
# Récupération des données de  2010 . 8
# Récupération des données de  2010 . 9
# Récupération des données de  2010 . 10
# Récupération des données de  2010 . 11
# Récupération des données de  2010 . 12
# Récupération des données de  2011 . 1
# Récupération des données de  2011 . 2
# Récupération des données de  2011 . 3
# Récupération des données de  2011 . 4
# Récupération des données de  2011 . 5
# Récupération des données de  2011 . 6
# Récupération des données de  2011 . 7
# Récupération des données de  2011 . 8
# Récupération des données de  2011 . 9
# Récupération des données de  2011 . 10
# Récupération des données de  2011 . 11
# Récupération des données de  2011 . 12
# Récupération des données de  2012 . 1
# Récupération des données de  2012 . 2
# Récupération des données de  2012 . 3
# Récupération des données de  2012 . 4
# Récupération des données de  2012 . 5
# Récupération des données de  2012 . 6
# Récupération des données de  2012 . 7
# Récupération des données de  2012 . 8
# Récupération des données de  2012 . 9
# Récupération des données de  2012 . 10
# Récupération des données de  2012 . 11
# Récupération des données de  2012 . 12
# Récupération des données de  2013 . 1
# Récupération des données de  2013 . 2
# Récupération des données de  2013 . 3
# Récupération des données de  2013 . 4
# Récupération des données de  2013 . 5
# Récupération des données de  2013 . 6
# Récupération des données de  2013 . 7
# Récupération des données de  2013 . 8
# Récupération des données de  2013 . 9
# Récupération des données de  2013 . 10
# Récupération des données de  2013 . 11
# Récupération des données de  2013 . 12
# Récupération des données de  2014 . 1
# Récupération des données de  2014 . 2
# Récupération des données de  2014 . 3
# Récupération des données de  2014 . 4
# Récupération des données de  2014 . 5
# Récupération des données de  2014 . 6
# Récupération des données de  2014 . 7
# Récupération des données de  2014 . 8
# Récupération des données de  2014 . 9
# Récupération des données de  2014 . 10
# Récupération des données de  2014 . 11
# Récupération des données de  2014 . 12
# Récupération des données de  2015 . 1
# Récupération des données de  2015 . 2
# Récupération des données de  2015 . 3
# Récupération des données de  2015 . 4
# Récupération des données de  2015 . 5
